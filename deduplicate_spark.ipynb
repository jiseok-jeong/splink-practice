# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local").appName("PySpark Installation Test").getOrCreate()
# df = spark.createDataFrame([(1, "Hello"), (2, "World")], ["id", "message"])
# df.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 from pyspark.sql import SparkSession
# ----> 3 spark = SparkSession.builder.master("local").appName("PySpark Installation Test").getOrCreate()
#       4 # df = spark.createDataFrame([(1, "Hello"), (2, "World")], ["id", "message"])
#       5 # df.show()
#
# File d:\Users\dcjc9\anaconda3\envs\splink\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# ...

# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession

from splink.backends.spark import similarity_jar_location

conf = SparkConf()
# This parallelism setting is only suitable for a small toy example
conf.set("spark.driver.memory", "12g")
conf.set("spark.default.parallelism", "8")
conf.set("spark.sql.codegen.wholeStage", "false")


# Add custom similarity functions, which are bundled with Splink
# documented here: https://github.com/moj-analytical-services/splink_scalaudfs
path = similarity_jar_location()
conf.set("spark.jars", path)

sc = SparkContext.getOrCreate(conf=conf)

spark = SparkSession(sc)
spark.sparkContext.setCheckpointDir("./tmp_checkpoints")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 18
#      15 path = similarity_jar_location()
#      16 conf.set("spark.jars", path)
# ---> 18 sc = SparkContext.getOrCreate(conf=conf)
#      20 spark = SparkSession(sc)
#      21 spark.sparkContext.setCheckpointDir("./tmp_checkpoints")
#
# File d:\Users\dcjc9\anaconda3\envs\splink\Lib\site-packages\pyspark\context.py:515, in SparkContext.getOrCreate(cls, conf)
#     513 with SparkContext._lock:
#     514     if SparkContext._active_spark_context is None:
# --> 515         SparkContext(conf=conf or SparkConf())
#     516     assert SparkContext._active_spark_context is not None
#     517     return SparkContext._active_spark_context
#
# ...

# %%
from splink.backends.spark import similarity_jar_location
print(similarity_jar_location())
# Out:
# d:\Users\dcjc9\anaconda3\envs\splink\Lib\site-packages\splink\internals/files/spark_jars/scala-udf-similarity-0.1.1_spark3.x.jar

# %%
spark = (
    SparkSession.builder
    .config("spark.driver.memory", "12g")
    .config("spark.default.parallelism", "8")
    .config("spark.sql.codegen.wholeStage", "false")
    .config("spark.jars", "C:/path/to/splink_scalaudfs.jar")  # Manually set the correct path
    .getOrCreate()
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 7
#       1 spark = (
#       2     SparkSession.builder
#       3     .config("spark.driver.memory", "12g")
#       4     .config("spark.default.parallelism", "8")
#       5     .config("spark.sql.codegen.wholeStage", "false")
#       6     .config("spark.jars", "C:/path/to/splink_scalaudfs.jar")  # Manually set the correct path
# ----> 7     .getOrCreate()
#       8 )
#
# File d:\Users\dcjc9\anaconda3\envs\splink\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# ...

# %%
spark = (
    SparkSession.builder
    .config("spark.driver.memory", "12g")
    .config("spark.default.parallelism", "8")
    .config("spark.sql.codegen.wholeStage", "false")
    .config("spark.jars", path)  # Ensure 'path' is correctly set
    .getOrCreate()
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       1 spark = (
#       2     SparkSession.builder
#       3     .config("spark.driver.memory", "12g")
#       4     .config("spark.default.parallelism", "8")
#       5     .config("spark.sql.codegen.wholeStage", "false")
#       6     .config("spark.jars", path)  # Ensure 'path' is correctly set
# ----> 7     .getOrCreate()
#       8 )
#
# File d:\Users\dcjc9\anaconda3\envs\splink\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# ...
